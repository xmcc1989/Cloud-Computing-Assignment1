# %%
import json
import boto3
import datetime
import pprint
import requests
import random
import argparse
import time
import sys
from botocore.exceptions import ClientError
# import amazondax
from boto3.dynamodb.conditions import Key
# from requests_aws4auth import AWS4Auth

NUM_RECOMEND = 3

def poll_sqs():
    client = boto3.client("sqs")    
    response = client.receive_message(
        QueueUrl="https://sqs.us-east-1.amazonaws.com/578480262707/chatBotTaskQueue",
        MaxNumberOfMessages=1,
        VisibilityTimeout=10,
        WaitTimeSeconds=10,
        MessageAttributeNames=[
            'All'
        ]
    )
    
    return response['Messages']

def delete_sqs(receipt_handle):
    client = boto3.client("sqs")
    response = client.delete_message(
        QueueUrl="https://sqs.us-east-1.amazonaws.com/578480262707/chatBotTaskQueue",
        ReceiptHandle=receipt_handle,
    )

    return response

def query_es(cuisine):
    
    region = 'us-east-1'
    service = 'es'
#     credentials = boto3.Session().get_credentials()
#     awsauth = AWS4Auth(credentials.access_key, credentials.secret_key, region, service, session_token=credentials.token)

    host = 'https://search-cloudcomputing-o4clej3mxqwimr4cg7yjgpxpzu.us-east-1.es.amazonaws.com' 
    index = 'restaurants'
    url = host + '/' + index + '/_search'
    
    # Put the user query into the query DSL for more accurate search results.
    # Note that certain fields are boosted (^).
    query = {
        "size": 1000,
        "query": {
            "multi_match": {
                "query": cuisine,
                "fields": ["cuisineType"]
            }
        }
    }

    # Elasticsearch 6.x requires an explicit Content-Type header
    headers = { "Content-Type": "application/json" }

    # Make the signed HTTP request
    response = requests.get(url, auth=('mx608', '!Xmcc891001'), data=json.dumps(query), headers=headers)
    
    return json.loads(response.text)

def pick_id(data_es):
    
    id_list=[]
    res_list = data_es['hits']['hits']
    
    while len(id_list) < NUM_RECOMEND:
        rid = int(random.random()*len(res_list))
        bid = res_list[rid]['_source']['businessID']
        if res_list[rid]['_source']['businessID'] not in id_list:
            id_list.append(res_list[rid]['_source']['businessID'])
        
    return id_list

def retrieve_detail(businessID_list):
    
    dyn_resource = boto3.resource('dynamodb')
    table = dyn_resource.Table('yelp-restaurants')
    
    result_list=[]
    for bid in businessID_list:
        item = table.get_item(Key={
                            'businessID': bid
                            })
        result_list.append(item)
        
    return result_list

def construct_response(client_info, restaurant_list):
    
    cuisine = client_info['cuisine'] #pass in 'body'
    num_of_ppl = client_info['numberOfPeople']
    date = client_info['date']
    time = client_info['time']
    restaurant1 = '1. ' + restaurant_list[0]['Item']['name'] + ', '+ restaurant_list[0]['Item']['address'] + '; '
    restaurant2 = '2. ' + restaurant_list[1]['Item']['name'] + ', '+ restaurant_list[1]['Item']['address'] + '; '
    restaurant3 = '3. ' + restaurant_list[2]['Item']['name'] + ', '+ restaurant_list[2]['Item']['address'] + '. '
    
    message = "Hello! Here are my {0} restaurant suggestions for {1} people,"\
              " for {2} at {3}: {4}{5}{6} Enjoy your meal!"\
              .format(cuisine,num_of_ppl,date,time,restaurant1,restaurant2,restaurant3)
    
    return message

def send_email(recipient, message):
    
    SENDER = "alicespring2022@gmail.com"
    AWS_REGION = "us-east-1"
    SUBJECT = "Your Restaurant Recommendation from Chatbot"
    
    # The email body for recipients with non-HTML email clients.
    BODY_TEXT = (message)
    
    CHARSET = "UTF-8"
    
    client = boto3.client('ses',region_name=AWS_REGION)
    
    try:
        #Provide the contents of the email.
        response = client.send_email(
            Destination={
                'ToAddresses': [
                    recipient,
                ],
            },
            Message={
                'Body': {
                    'Text': {
                        'Charset': CHARSET,
                        'Data': BODY_TEXT,
                    },
                },
                'Subject': {
                    'Charset': CHARSET,
                    'Data': SUBJECT,
                },
            },
            Source=SENDER,
        )

    # Display an error if something goes wrong.	
    except ClientError as e:
        print(e.response['Error']['Message'])
    else:
        return "Email sent!"


def lambda_handler(event, context):
    
    #get user's request
    sqs_response = poll_sqs()
    sqs_msg = json.loads(sqs_response[0]['Body'])
    
    #delete from sqs
    sqs_del_response = delete_sqs(sqs_response[0]['ReceiptHandle'])
    
    #query elasticsearch to get restaurant list
    res = query_es(sqs_msg['cuisine'])
    
    #pick restaurants
    id_list = pick_id(res)
    
    #query dynamoDB to retrieve details
    restaurant_detail = retrieve_detail(id_list)
    
    #construct message
    message = construct_response(sqs_msg, restaurant_detail)
    
    #send recomendation to user
    response = send_email(sqs_msg['emailAddress'], message)
    
    return response

# %%
lambda_handler(1,1)
# Out:
# Email address is not verified. The following identities failed the check in region US-EAST-1: xxx@gmail.com

# %%
response = poll_sqs()
pprint.pprint(response,indent=2)
# d_rsp = delete_sqs(response['Messages'][0]['ReceiptHandle'])
# pprint.pprint(d_rsp,indent=2)
# Out:
# [ { 'Body': '{"location": "manhattan", "cuisine": "chinese", "date": '
#             '"2022-10-17", "time": "23:00", "numberOfPeople": "2", '
#             '"emailAddress": "xxx@gmail.com"}',
#     'MD5OfBody': '484c5c45dd65c26a75cb8856c8944fe1',
#     'MessageId': 'dbf406e8-3eae-4c82-a444-b9525c377359',
#     'ReceiptHandle': '...'}]

# %%
res = query_es('italian')
pprint.pprint(res,indent=2)
# Out:
# { '_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#   'hits': { 'hits': [ { '_id': '3351',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': '22nKUyCIbpnzR6R3_g1ptQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3354',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'vjubSxmdG_HoBBgd39geBw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3361',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'GjEE8vvjqb7eeHA3BGNxAw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3363',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': '8oO6j7AlnAbMSJs9Oj9GIw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3364',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'lwfCl81r5a0mjxDNxNGC9w',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3370',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'SCQ9B9jxqNHvJKQ-RagxaA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3371',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'yZJbealagfujEkgesAl2hA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3386',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'Zp-K3ztVTzR-LrWwl_CBgA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3393',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': '5EQOEAkH2Qh3Rv1TcnE7yA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3395',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'JwCnSW-RQ7_DxvbzWNO1hA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3397',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'xsQTIeq-WLkp4ParkTQpMQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3400',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'vVVmHacu2YAxKfpIjhfd1g',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3407',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': '7cjT33LfYSk7vrRdEaSr4w',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3426',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'dh5r9-SbN8xJ76XvnayWLQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3427',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'd5ya04K-2A_hI3Xzqe1HeA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3429',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'VmgvCsAP6vZ3DL1mw8ugWQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3433',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'vXYFa2qzppkGiOiVPrLwDQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3437',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'K9Ur20N51Li3sAvaV9-6Ng',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3439',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'NlmP5x_Ykznd55Dc85ChUg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3442',
#                         '_index': 'restaurants',
#                         '_score': 2.4014127,
#                         '_source': { 'businessID': 'rZ9OFoSqy8u4WECfh--ylg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '
',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3704',
#                         '_index': 'restaurants',
#                         '_score': 2.360716,
#                         '_source': { 'businessID': 'E9NMNWvV70HV5gB369N0EA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3708',
#                         '_index': 'restaurants',
#                         '_score': 2.360716,
#                         '_source': { 'businessID': 'ZlwjT-jygnYqM5qDE0CuLQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3353',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'OWNmOq-TAsHjGcYdCVclSw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3355',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'qBGKigOGn_flCx1apxPzlA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3356',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'AUifp6IDKzmorCM6vY2fug',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3374',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'Fit_iIDn__NPVZpVlKFBFQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3379',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'jnHbdsqlTKlPcmJ8BCP9-g',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3385',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': '15k7iqFbhf4h8L01yggLqg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3394',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'Be1Y-vAEMgo7lqL5alXgDA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3398',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'faukkggAc_tuJ4THYlf4fg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3399',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'XHhRAKq6DArQXYhkgvwaow',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3403',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'IAbOg5Kd5AynOcbI8vGTwQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3406',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'q8myw-sQtrmn0w-tKSC5cA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3411',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'nSk_zCJESMKGLHyJTPPlZA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3412',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'NAlOPUbFQVE0bUu8_wmBLQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3417',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': '-hUvO0C0A-pGZdiSKvjoFw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3425',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'MeUq9lombxM9alxs64tejQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3430',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'NGyFpNCrzqEG3B0Z0drKfw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3436',
#                         '_index': 'restaurants',
#                         '_score': 2.3438969,
#                         '_source': { 'businessID': 'abZ-mEvF6Tj4hfyIg0lKwQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
# ...
#                         '_type': 'Restaurant'},
#                       { '_id': '3485',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'cyLw0vW5MrsF35-A6Dy03w',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3486',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'idxD3X7WfLFPZMoFnCRIQQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3489',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'TZto7AjdA337XIw66AOpUw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3492',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '6n7D4amt9vEruR73tt3S9w',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3497',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'FQ_9HzcX6_vLFnNIJ30jiA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3503',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'QgClXDNikG0wRpIZ-Rcm7A',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3506',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'v1M1HIQBVwYatEF_iOmedw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3515',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'R3gSQGB3aEmVpwbKIgOPqg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3516',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'XQKUqU1vPvgnapxmmBI55Q',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3537',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '15d_Y6TVOQFD2KRVkxuAjw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3539',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '5zcZZJhriNQ2R92r9drxug',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3541',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '_N92SH1Zi-Hbxn_bNHFz0Q',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3542',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '4WDHrSodF1Xidv9ezS6Sgg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3546',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'kvWSD8qHKugLcmDsNBMdfQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3551',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'C3OlQ_y5LcgboyaKlpETYA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3557',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '7Tu5l9UfWVi_v3m4TwJAxQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3558',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'kLJfizeHMQqesp1K9mfUtg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3559',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'LRgB2kEKtBxqIxNksTO_PQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3562',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'ntQ7O1YPMIOrQkynhXRBVg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3565',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'qLYloGaI-4OmLbNnr_wrGA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3569',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'hot1lIebdQNau05onRum7w',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3571',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'HSKcCmRFqzqG542Hy_eftw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3575',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'nM2AdRp2iSJHi4MgvIrEBg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3576',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'mPHPVJ2-8mOR-lFHafrc6w',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3577',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'X-0X9nR9tnCTW3bXJzA09Q',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3578',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'UjzSeETESWzramhdOdWKKQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3583',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'pP92FmGKpH5nQfaPXMfQAg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3584',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'QhRQE6nOMLd00kV2k-IsbQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3586',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'gTEoEsssfbjl76Opf5bP9g',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3588',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '3FJjOq78eeqakDCsJHqJug',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3591',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'IEb99GmOvg585gmwmm4iNA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3601',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'FhXjAc6nKLf414KxYujUHw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3615',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'VCaE8QSCAIThGbMq80nFYg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3616',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'rupPZLhd0oRSAmVDaeYaGA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3620',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'wZkZmjZEJDraLJgAalnHvA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3642',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'ZQ8E37pWd4KBgtdcWKx5IA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3647',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'j6fSechU9HxzbnK-kjQx1Q',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3648',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'X9f5HH4x3Mi7lo4ph9efvQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3650',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'q0HBfS9eJ9AeuaWQ3Ronqw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3652',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '2F-7XCoPS1mbdy9ioqWuqw',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3682',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '-58--bg-KKUNArp18U4llA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3683',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'Jwb556DrGTEZryeV7XgZmQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3692',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'geTFpY84Tp-nVTXflnxtDA',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3695',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'XzkmePjJC0ryuqZp5qd12A',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3698',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'TUJutjq0LU6zexzM8Wia4w',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3700',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': '7S8g0G_Ndc3DS-kqsozq8Q',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3701',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'bxxP-1LQURlkom-geT2J8Q',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3702',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'OmB4X44Ru8gjD6qgSNlXdg',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'},
#                       { '_id': '3703',
#                         '_index': 'restaurants',
#                         '_score': 2.2488809,
#                         '_source': { 'businessID': 'gJg_Gh2lqrCprDzR6ZP9QQ',
#                                      'cuisineType': 'italian'},
#                         '_type': 'Restaurant'}],
#             'max_score': 2.4014127,
#             'total': {'relation': 'eq', 'value': 361}},
#   'timed_out': False,
#   'took': 59}

# %%
idlist = pick_id(res)
idlist
# Out:
# ['q6ux26c-SfK-679y9lvVbw', '5ZEFbq_AQV5VQFG2JKYzlA', '22nKUyCIbpnzR6R3_g1ptQ']

# %%
item = retrieve_detail(idlist)
item
# Out:
# [{'Item': {'businessID': 'q6ux26c-SfK-679y9lvVbw',
#    'rating': Decimal('3.5'),
#    'zip_code': '10026',
#    'insertedAtTimestamp': '2022-10-19 21:24:12.789806',
#    'address': '196 Lenox Ave, New York, NY 10026',
#    'cuisineType': 'italian',
#    'name': 'Settepani',
#    'review_count': Decimal('273'),
#    'coordinates': '40.80435,-73.94766'},
#   'ResponseMetadata': {'RequestId': '3I6A02VEB86BG5BQRH24B27LPBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'server': 'Server',
#     'date': 'Fri, 21 Oct 2022 03:13:30 GMT',
#     'content-type': 'application/x-amz-json-1.0',
#     'content-length': '332',
#     'connection': 'keep-alive',
#     'x-amzn-requestid': '3I6A02VEB86BG5BQRH24B27LPBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#     'x-amz-crc32': '3568225498'},
#    'RetryAttempts': 0}},
#  {'Item': {'businessID': '5ZEFbq_AQV5VQFG2JKYzlA',
#    'rating': Decimal('4'),
#    'zip_code': '10010',
#    'insertedAtTimestamp': '2022-10-19 21:24:02.552284',
#    'address': '27 E 21st St, New York, NY 10010',
#    'cuisineType': 'italian',
#    'name': "Giorgio's of Gramercy",
#    'review_count': Decimal('803'),
#    'coordinates': '40.7394209879325,-73.9885425567627'},
#   'ResponseMetadata': {'RequestId': '01I5JBI15KSQUGOSQ4TAB22SHBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'server': 'Server',
#     'date': 'Fri, 21 Oct 2022 03:13:30 GMT',
#     'content-type': 'application/x-amz-json-1.0',
#     'content-length': '357',
#     'connection': 'keep-alive',
#     'x-amzn-requestid': '01I5JBI15KSQUGOSQ4TAB22SHBVV4KQNSO5AEMVJF66Q9ASUAAJG',
#     'x-amz-crc32': '2221821384'},
#    'RetryAttempts': 0}},
#  {'Item': {'businessID': '22nKUyCIbpnzR6R3_g1ptQ',
#    'rating': Decimal('4'),
#    'zip_code': '10036',
#    'insertedAtTimestamp': '2022-10-19 21:22:56.714503',
#    'address': '200 W 44th St, New York, NY 10036',
#    'cuisineType': 'italian',
#    'name': "Carmine's Italian Restaurant - Times Square",
#    'review_count': Decimal('4254'),
#    'coordinates': '40.75749848725768,-73.98665333142026'},
#   'ResponseMetadata': {'RequestId': '6RADAPRKLSAL5PVB6P8FB84CMVVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'server': 'Server',
#     'date': 'Fri, 21 Oct 2022 03:13:30 GMT',
#     'content-type': 'application/x-amz-json-1.0',
#     'content-length': '383',
#     'connection': 'keep-alive',
#     'x-amzn-requestid': '6RADAPRKLSAL5PVB6P8FB84CMVVV4KQNSO5AEMVJF66Q9ASUAAJG',
#     'x-amz-crc32': '903133962'},
#    'RetryAttempts': 0}}]

# %%
construct_response(response[0]['Body'], item)
# Out:
# 'Hello! Here are my chinese restaurant suggestions for 2 people, for 2022-10-17 at 23:00: 1. 235 Mulberry St, New York, NY 10012; 2. 175 Ludlow St, New York, NY 10002; 3. 1274 Amsterdam Ave, New York, NY 10027.  Enjoy your meal!'

# %%
a= "{0}{1}".format('a','b')
a
# Out:
# 'ab'

# %%
send_email('mx608@nyu.edu', 'hello')
# Out:
# Email sent! Message ID:
# 01000183f89d058c-6e530398-2b3c-4037-87f3-b75132b605f5-000000
